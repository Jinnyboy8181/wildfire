# %%
import os
os.getcwd( )


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_csv('Data/Total_Wildfire.csv')
raw_data.head()
# Out:
#    Year   Fires       Acres
# 0  2020  58,950  10,122,336
# 1  2019  50,477   4,664,364
# 2  2018  58,083   8,767,492
# 3  2017  71,499  10,026,086
# 4  2016  67,743   5,509,995

# %%
sns.histplot(data=raw_data, x='Year', kde=True, hue='Year')
plt.show('
)
